# %%
# Import necessary libraries:
import numpy as np                                      #for numerical operations
from sklearn.datasets import load_iris                  #to load iris dataset
from sklearn.linear_model import LogisticRegression     #our classifier
from sklearn.model_selection import train_test_split    #for splitting data into training and train_test_split
from sklearn.metrics import classification_report       #for evaluating our model

# Load Iris dataset
iris = load_iris()                #the iris dataset is a classic dataset with 150 samples of iris flowers
x = iris.data                     #feature matrix: measurements like sepal length, sepal width, petal length, petal width
y = iris.target                   #target vector: numerical label representing the iris species.

# Split the data in to training and testing subsets
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 42) 
# test_size = 0.3....30% of the data is reserved for testing
# random_state = 42........ensures reproducibility of the split

# Initialize the logistic regression classifier
clf = LogisticRegression(max_iter=200)
# max_iter=200 sets the maximum number of iterations(to ensure convergence for this dataset).

# train the classifier on the training data
clf.fit(x_train, y_train) # THe model learns the mapping from features to iris species

# Used the trained model to predict the test labels
y_pred = clf.predict(x_test)

# Print the classification report to evaluate perfomance
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
